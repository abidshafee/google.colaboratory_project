# %% [markdown]
# <a href="https://colab.research.google.com/github/abidshafee/google.colaboratory_projects/blob/master/Matplotlib_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('fivethirtyeight')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5c44fe92-79ff-4bd1-ad14-ba46ad62063d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c44fe92-79ff-4bd1-ad14-ba46ad62063d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving EURUSD=X.csv to EURUSD=X.csv

# %%
df = pd.read_csv('EURUSD=X.csv')
df
# Out:
#            Date      Open      High       Low     Close  Adj Close  Volume
# 0    2019-07-11  1.126126  1.128796  1.125176  1.125885   1.125885       0
# 1    2019-07-12  1.125024  1.127800  1.123974  1.125239   1.125239       0
# 2    2019-07-15  1.127180  1.128599  1.125568  1.127205   1.127205       0
# 3    2019-07-16  1.126088  1.126634  1.120900  1.126177   1.126177       0
# 4    2019-07-17  1.121328  1.123343  1.120109  1.121227   1.121227       0
# ..          ...       ...       ...       ...       ...        ...     ...
# 257  2020-07-06  1.124885  1.134687  1.124885  1.124720   1.124720       0
# 258  2020-07-07  1.131030  1.133658  1.126037  1.131286   1.131286       0
# 259  2020-07-08  1.127281  1.134559  1.126519  1.127523   1.127523       0
# 260  2020-07-09  1.133787  1.137268  1.128796  1.133915   1.133915       0
# 261  2020-07-10  1.128923  1.132477  1.125720  1.128796   1.128796       0
#
# [262 rows x 7 columns]

# %%
plt.figure(figsize=(16,8))
plt.plot(df['Date'], df['Close'], marker='.', label = 'Close Price')
plt.plot(df['Date'], df['High'], 'g--', label='High')
plt.title('Day wise Close price')
plt.xlabel('Dates')
plt.ylabel('EURUSD Closed price')
# plt.legend(['Closed', 'High'])
plt.legend()
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# Available builtin styles in matplotlib

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']
